# %% [markdown]
# <a href="https://colab.research.google.com/github/Saadkhan-777/print/blob/main/practice%20print%20func.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("heloo world")
# Out:
# heloo world
